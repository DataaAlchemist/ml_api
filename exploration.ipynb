# %%
import pandas as pd
import numpy as np
import re

import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', 100)

# %%
books = pd.read_csv('data/books_data.csv')

books['id'] = books.index
# books = books[['id', 'Title', 'description', 'authors', 'image', 'publisher', 'categories', 'ratingsCount']]
# books.columns = ['id', 'title', 'description', 'author', 'image', 'publisher', 'genre', 'ratings_count']

display(books.head())
display(books.shape)
# Out:
#                                                Title
# 0                     Its Only Art If Its Well Hung!  \
# 1                           Dr. Seuss: American Icon
# 2              Wonderful Worship in Smaller Churches
# 3                      Whispers of the Wicked Saints
# 4  Nation Dance: Religion, Identity and Cultural ...
#
#                                          description              authors
# 0                                                NaN     ['Julie Strain']  \
# 1  Philip Nel takes a fascinating look into the k...       ['Philip Nel']
# 2  This resource includes twelve principles in un...     ['David R. Ray']
# 3  Julia Thomas finds her life spinning out of co...  ['Veronica Haddon']
# 4                                                NaN      ['Edward Long']
#
#                                                image
# 0  http://books.google.com/books/content?id=DykPA...  \
# 1  http://books.google.com/books/content?id=IjvHQ...
# 2  http://books.google.com/books/content?id=2tsDA...
# 3  http://books.google.com/books/content?id=aRSIg...
# 4                                                NaN
#
#                                          previewLink  publisher publishedDate
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...        NaN          1996  \
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black    2005-01-01
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...        NaN          2000
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...  iUniverse       2005-02
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...        NaN    2003-03-01
#
#                                             infoLink
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...  \
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...
#
#                       categories  ratingsCount  id
# 0    ['Comics & Graphic Novels']           NaN   0
# 1  ['Biography & Autobiography']           NaN   1
# 2                   ['Religion']           NaN   2
# 3                    ['Fiction']           NaN   3
# 4                            NaN           NaN   4
# (212404, 11)

# %%
books.isnull().sum()
# Out:
# Title                 1
# description       68442
# authors           31413
# image             52075
# previewLink       23836
# publisher         75886
# publishedDate     25305
# infoLink          23836
# categories        41199
# ratingsCount     162652
# id                    0
# dtype: int64

# %%
books.dropna(inplace=True)
books.reset_index()
books.shape
# Out:
# (40635, 11)

# %%
def clean_authors(authors):
    authors = re.sub(r'\[|\]', '', authors)
    authors = authors.split(',')
    authors = [re.sub(r'\'|\"', '', author) for author in authors]

    return authors[0]

def clean_genre(genre):
    genre = re.sub(r'\[|\]', '', genre)
    genre = genre.split(',')
    genre = [re.sub(r'\'|\"', '', g) for g in genre]
    return genre[0]

# %%
books['author'] = books['author'].apply(clean_authors)
books['genre'] = books['genre'].apply(clean_genre)
books.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'author'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 books['author'] = books['author'].apply(clean_authors)
#       2 books['genre'] = books['genre'].apply(clean_genre)
#       3 books.head()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'author'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pickle

# %%
def clean_title(title):
    title = re.sub('[^A-Za-z0-9]+' , ' ', title)
    title = title.lower()
    return title

# %%
# clean the title by lowercasing and removing characters that are not letters or numbers
books['clean_title'] = books['title'].apply(clean_title)
books['clean_description'] = books['description'].apply(clean_title)
books.head()
# Out:
#    id                                              title
# 0   0  The Church of Christ: A Biblical Ecclesiology ...  \
# 1   1  Voices from the Farm: Adventures in Community ...
# 2   2                            The Battleship Bismarck
# 3   3                            Tess and the Highlander
# 4   4   Beginner's Yoruba (Hippocrene Beginner's Series)
#
#                                          description               author
# 0  In The Church of Christ: A Biblical Ecclesiolo...     Everett Ferguson  \
# 1  Twenty-five years ago, at the height of the co...          Rupert Fike
# 2  The Bismarck is perhaps the most famous – and ...     Stefan Draminski
# 3  In 1543, on a windswept isle off of Scotland, ...       May Mcgoldrick
# 4  "Beginner's Yoruba" is now available with two ...  Kayode J. Fakinlede
#
#                                                image
# 0  http://books.google.com/books/content?id=kVqRa...  \
# 1  http://books.google.com/books/content?id=IjTAB...
# 2  http://books.google.com/books/content?id=nxttD...
# 3  http://books.google.com/books/content?id=VmCRS...
# 4  http://books.google.com/books/content?id=xLe4n...
#
#                     publisher                      genre  ratings_count
# 0  Wm. B. Eerdmans Publishing                   Religion            5.0  \
# 1     Book Publishing Company  Biography & Autobiography            1.0
# 2       Bloomsbury Publishing                    History            1.0
# 3              Harper Collins           Juvenile Fiction            2.0
# 4            Hippocrene Books     Foreign Language Study            1.0
#
#                                          clean_title
# 0  the church of christ a biblical ecclesiology f...  \
# 1  voices from the farm adventures in community l...
# 2                            the battleship bismarck
# 3                            tess and the highlander
# 4    beginner s yoruba hippocrene beginner s series
#
#                                    clean_description
# 0  in the church of christ a biblical ecclesiolog...
# 1  twenty five years ago at the height of the cou...
# 2  the bismarck is perhaps the most famous and no...
# 3  in 1543 on a windswept isle off of scotland se...
# 4   beginner s yoruba is now available with two a...

# %%
books.to_csv('data/books_clean.csv', index=False)

# %%
vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(1, 2), min_df=2)
tfidf_matrix = vectorizer.fit_transform(books['clean_title'])

vectorizer_desc = TfidfVectorizer(stop_words='english', ngram_range=(1, 2), min_df=2)
desc_tfidf_matrix = vectorizer_desc.fit_transform(books['clean_description'])

# %%
display(pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out()).head())
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 display(pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out()).head())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\sparse\_compressed.py:1051, in _cs_matrix.toarray(self, order, out)
#    1049 if out is None and order is None:
#    1050     order = self._swap('cf')[0]
# -> 1051 out = self._process_toarray_args(order, out)
#    1052 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1053     raise ValueError('Output array must be C or F contiguous')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\sparse\_base.py:1298, in spmatrix._process_toarray_args(self, order, out)
#    1296     return out
#    1297 else:
# -> 1298     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 7.76 GiB for an array with shape (40681, 25614) and data type float64

# %%
pickle.dump(tfidf_matrix, open('models/tfidf_matrix.pickle', 'wb'))
pickle.dump(desc_tfidf_matrix, open('models/desc_tfidf_matrix.pickle', 'wb'))

# %%
title = 'The Alchemist'

# get recommendations based on title and rating
def get_recommendations(title, tfidf_matrix, books):
    title = clean_title(title)
    query_vec = vectorizer.transform([title])
    similarity = cosine_similarity(query_vec, tfidf_matrix).flatten()
    indices = similarity.argsort()[::-1]
    books = books.iloc[indices]
    return books

get_recommendations(title, tfidf_matrix, books).head(10)
# Out:
#             id                                              title  \
# 26834    26834                                      The Alchemist
# 108225  108225                                 The Last Alchemist
# 21523    21523                               The Alchemist's Door
# 169400  169400                  The Alchemist's Daughter: A Novel
# 152507  152507  The Alchemist's Handbook: Manual for Practical...
# 79469    79469  The Alchemist to Mercury: An Alternate Opus: U...
# 65711    65711                                         Shipwrecks
# 65742    65742            .Hack: //Legend of the Twilight, Vol. 1
# 65732    65732                Charcuterie and French Pork Cookery
# 65728    65728  Narrative of the Life of Frederick Douglass, A...
#
#                                               description              author  \
# 26834   "My heart is afraid that it will have to suffe...        Paulo Coelho
# 108225  Spinifex, the nineteenth alchemist, must disco...      Colin Thompson
# 21523   Fleeing to Prague to escape a demon attack, si...      Lisa Goldstein
# 169400  Based on some of literature’s horror and scien...       Theodora Goss
# 152507  Formerly handed down under oath of secrecy, th...     Frater Albertus
# 79469   Since 1970, many readers have waited for anoth...    Douglas Messerli
# 65711   Living in a remote, desperately poor fishing v...     Akira Yoshimura
# 65742   The CC Corporation thinks that Shugo, Rena and...           Rei Idumi
# 65732   This timeless classic of French cuisine brings...        Jane Grigson
# 65728   Narrative of the Life of Frederick Douglass Fi...  FREDERICK DOUGLASS
#
#                                                     image  \
# 26834   http://books.google.com/books/content?id=pTr44...
# 108225  http://books.google.com/books/content?id=PhnOf...
# 21523   http://books.google.com/books/content?id=WrS1F...
# 169400  http://books.google.com/books/content?id=LicvD...
# 152507  http://books.google.com/books/content?id=-EGcb...
# 79469   http://books.google.com/books/content?id=drBZA...
# 65711   http://books.google.com/books/content?id=k0fQb...
# 65742   http://books.google.com/books/content?id=tFAUR...
# 65732   http://books.google.com/books/content?id=HC0Sv...
# 65728   http://books.google.com/books/content?id=UP4yE...
#
#                              publisher                      genre  \
# 26834                   Harper Collins                    Fiction
# 108225          Random House Australia                 Alchemists
# 21523                        Macmillan                    Fiction
# 169400              Simon and Schuster                    Fiction
# 152507                    Weiser Books                   Religion
# 79469   Los Angeles : Sun & Moon Press                     Poetry
# 65711        Houghton Mifflin Harcourt                    Fiction
# 65742                         TokyoPop    Comics & Graphic Novels
# 65732              Grub Street Cookery                    Cooking
# 65728                 BEYOND BOOKS HUB  Biography & Autobiography
#
#         ratings_count                                        clean_title  \
# 26834          4895.0                                      the alchemist
# 108225            4.0                                 the last alchemist
# 21523             5.0                               the alchemist s door
# 169400           37.0                   the alchemist s daughter a novel
# 152507            1.0  the alchemist s handbook manual for practical ...
# 79469             1.0  the alchemist to mercury an alternate opus unc...
# 65711            17.0                                         shipwrecks
# 65742             5.0                  hack legend of the twilight vol 1
# 65732             1.0                charcuterie and french pork cookery
# 65728            51.0  narrative of the life of frederick douglass an...
#
#                                         clean_description
# 26834    my heart is afraid that it will have to suffe...
# 108225  spinifex the nineteenth alchemist must discove...
# 21523   fleeing to prague to escape a demon attack six...
# 169400  based on some of literature s horror and scien...
# 152507  formerly handed down under oath of secrecy thi...
# 79469   since 1970 many readers have waited for anothe...
# 65711   living in a remote desperately poor fishing vi...
# 65742   the cc corporation thinks that shugo rena and ...
# 65732   this timeless classic of french cuisine brings...
# 65728   narrative of the life of frederick douglass fi...

# %%
the_alchemist = books[books['title'] == 'The Alchemist']

def get_recommendations_by_description(description, desc_tfidf_matrix, books):
    description = clean_title(description)
    query_vec = vectorizer_desc.transform([description])
    similarity = cosine_similarity(query_vec, desc_tfidf_matrix).flatten()
    indices = similarity.argsort()[::-1]
    books = books.iloc[indices]
    return books

get_recommendations_by_description(the_alchemist['description'].values[0], desc_tfidf_matrix, books).head(10)
# Out:
#             id                                              title  \
# 26834    26834                                      The Alchemist
# 68200    68200                                      The Valkyries
# 44478    44478                         The Sorceress & the Savage
# 190773  190773                            An Enemy at Green Knowe
# 169689  169689          The Red Lion & The Elixir of Eternal Life
# 148791  148791                                           Adultery
# 161204  161204                           Adultery & Other Choices
# 147946  147946                                 Lexicon of Alchemy
# 3700      3700                                          The Abyss
# 65266    65266  The Pilgrimage: A Contemporary Quest for Ancie...
#
#                                               description  \
# 26834   "My heart is afraid that it will have to suffe...
# 68200   A classic masterwork of spiritual tension and ...
# 44478   While armies of the Shadowrealms gather and Ma...
# 190773  The inhabitants of Green Knowe become involved...
# 169689  The harrowing adventures of a 16th century alc...
# 148791  I want to change. I need to change. I'm gradua...
# 161204  I want to change. I need to change. I'm gradua...
# 147946  Martinus Rulandus was a German physician and a...
# 3700    The story of the fate of two cousins in sixtee...
# 65266   Previously published as "The Diary of a Magus"...
#
#                       author  \
# 26834           Paulo Coelho
# 68200           Paulo Coelho
# 44478          Michael Scott
# 190773     Lucy Maria Boston
# 169689          Maria Szepes
# 148791          Paulo Coelho
# 161204          Paulo Coelho
# 147946       Martin Rulandus
# 3700    Marguerite Yourcenar
# 65266           Paulo Coelho
#
#                                                     image  \
# 26834   http://books.google.com/books/content?id=pTr44...
# 68200   http://books.google.com/books/content?id=FdhkG...
# 44478   http://books.google.com/books/content?id=DnsNa...
# 190773  http://books.google.com/books/content?id=JiV8C...
# 169689  http://books.google.com/books/content?id=fvKKG...
# 148791  http://books.google.com/books/content?id=cxUcA...
# 161204  http://books.google.com/books/content?id=cxUcA...
# 147946  http://books.google.com/books/content?id=vWmjA...
# 3700    http://books.google.com/books/content?id=z248v...
# 65266   http://books.google.com/books/content?id=0NtNz...
#
#                         publisher                               genre  \
# 26834              Harper Collins                             Fiction
# 68200              Harper Collins                             Fiction
# 44478                       Ember                    Juvenile Fiction
# 190773  Houghton Mifflin Harcourt                    Juvenile Fiction
# 169689     Horus Pub Incorporated                             Fiction
# 148791                    Vintage                             Fiction
# 161204                    Vintage                             Fiction
# 147946            Jazzybee Verlag                                Body
# 3700                    Macmillan                             Fiction
# 65266            HarperCollins UK  Christian pilgrims and pilgrimages
#
#         ratings_count                                        clean_title  \
# 26834          4895.0                                      the alchemist
# 68200            16.0                                      the valkyries
# 44478            47.0                           the sorceress the savage
# 190773            2.0                            an enemy at green knowe
# 169689            1.0            the red lion the elixir of eternal life
# 148791         2987.0                                           adultery
# 161204         2987.0                             adultery other choices
# 147946            1.0                                 lexicon of alchemy
# 3700              1.0                                          the abyss
# 65266             1.0  the pilgrimage a contemporary quest for ancien...
#
#                                         clean_description
# 26834    my heart is afraid that it will have to suffe...
# 68200   a classic masterwork of spiritual tension and ...
# 44478   while armies of the shadowrealms gather and ma...
# 190773  the inhabitants of green knowe become involved...
# 169689  the harrowing adventures of a 16th century alc...
# 148791  i want to change i need to change i m graduall...
# 161204  i want to change i need to change i m graduall...
# 147946  martinus rulandus was a german physician and a...
# 3700    the story of the fate of two cousins in sixtee...
# 65266   previously published as the diary of a magus t...
